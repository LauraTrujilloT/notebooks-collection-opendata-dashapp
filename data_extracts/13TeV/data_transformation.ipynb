# %%
import pandas as pd

# %%
data_a = pd.read_csv('hyy_data_sample_a.csv')
data_a = data_a.assign(energy_TeV=13)
data_b = pd.read_csv('hyy_data_sample_b.csv')
data_b = data_b.assign(energy_TeV=13)
data_c = pd.read_csv('hyy_data_sample_c.csv')
data_c = data_c.assign(energy_TeV=13)

# %%
final_df = pd.concat([data_a, data_b, data_c])
final_df.to_csv('hyy_dataset.csv', index=False)

# %%
final_df
# Out:
#                      photon_pt                 photon_eta  \
# 0      [176121.16   39629.145]  [-0.833492    0.09470307]
# 1        [100427.68  95522.57]      [1.7343543 0.6880436]
# 2        [45906.086 34899.742]  [ 0.5604442  -0.18553612]
# 3          [78156.23 66979.34]    [0.22070466 1.0673687 ]
# 4        [59702.844 36279.23 ]  [-0.4967246   0.94473416]
# ...                        ...                        ...
# 91108    [67718.91  41175.957]    [-1.0333748 -0.6217399]
# 91109      [96178.83 58639.23]    [-1.69634   -1.3133827]
# 91110    [55886.613 42451.977]    [-1.9944512 -2.1158452]
# 91111    [50574.566 34189.047]  [-0.12606226 -0.99943656]
# 91112    [136036.95  76035.99]  [ 0.38889045 -0.22393055]
#
#                       photon_phi                 photon_E photon_isTightID  \
# 0      [-0.29423872  0.56729376]    [240922.31  39806.99]    [ True  True]
# 1        [ 0.6559552 -2.4571521]    [293338.34 119039.13]    [ True  True]
# ...
